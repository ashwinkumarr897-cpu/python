# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinkumarr897-cpu/python/blob/main/ashwin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.fahrenheit to celsius

# %%
fahrenheit = float(input("Enter the fahrenheit:"))
celsius = (fahrenheit-32)*5/9
print("celsius",celsius)
# Out:
# Enter the fahrenheit:33
# celsius 0.5555555555555556

# %% [markdown]
# 2.celsius to fahrenheit

# %%
celsius = float(input("Enter the celsius:"))
fahrenheit = (celsius * 5/9) +32
print("fahrenheit",fahrenheit)
# Out:
# Enter the celsius:33
# fahrenheit

# %% [markdown]
# 3.kilometer to miles

# %%
kilometer = float(input("Enter the kilometer:"))
miles = kilometer * 0.621371
print("miles",miles)
# Out:
# Enter the kilometer:33
# miles 20.505243

# %% [markdown]
# 4.miles to kilometer

# %%
miles = float(input("Enter the miles:"))
kilometer = miles * 1.60934
print("kilometer",kilometer)
# Out:
# Enter the miles:33
# kilometer 53.10822

# %% [markdown]
# 5.miligram to gram

# %%
miligram = float(input("Enter the miligram:"))
gram = miligram*0.001
print("miligram",miligram)
# Out:
# Enter the miligram:33
# miligram 33.0

# %% [markdown]
# 6.mins to hrs

# %%
min = int(input("enter the mins:"))
hrs= min//60
print("hrs=",hrs)
# Out:
# enter the mins:60
# hrs= 1

# %% [markdown]
# 7.leap year

# %%
year=int(input ("Enter the year:"))
if(year%400==0 or year%4 ==0 or year%100==0):
  print("its a leap year")
else:
  print("its not a leap year")
# Out:
# Enter the year:2007
# its not a leap year

# %% [markdown]
# 8.salary calculater

# %%
ys=int(input("enter the yearly salary:"))

month=ys/12
week=ys/52
days=ys/365
hrs=ys/(365*24)

print("salary for a month",month)
print("salary for a week",week)
print("salary for a day",days)
print("salary for a hour",hrs)
# Out:
# enter the yearly salary:100000
# salary for a month 8333.333333333334
# salary for a week 1923.076923076923
# salary for a day 273.972602739726
# salary for a hour 11.415525114155251

# %% [markdown]
# bitwise operator

# %%
a=10
b=20
print(a&b)
print(a|b)
print(a^b)
print(a>>b)
print(a<<b)
print(~a)
# Out:
# 0
# 30
# 30
# 0
# 10485760
# -11
